# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle
import pandas as pd

# Load the training and testing data

training_file = "./traffic-signs-data/train.p"
validation_file = "./traffic-signs-data/valid.p"
testing_file = "./traffic-signs-data/test.p"
SignNames = pd.read_csv('./signnames.csv')

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

assert(len(X_train) == len(y_train))
assert(len(X_valid) == len(y_valid))
assert(len(X_test) == len(y_test))

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results
import numpy as np

# Number of training examples
n_train = len(X_train)

# Number of testing examples.
n_test = len(X_test)

# What's the shape of an traffic sign image?
image_shape = X_train[0].shape

# How many unique classes/labels there are in the dataset.
classes = list(set(y_train))
n_classes = len(classes)

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections.

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
import random
# Visualizations will be shown in the notebook.
SignsDict = SignNames['SignName']
#print('SignsDict:\n', SignsDict)

SignNamesList = []
for i in range(0, len(SignsDict)):
    SignNamesList.append(SignsDict[i])
#print('Signs:\n', SignNamesList)

fig = plt.figure()
plt.hist(y_train, classes, alpha=0.5, label='training data')
plt.hist(y_test, classes, alpha=0.5, label='test data')
plt.legend(loc='upper right')
plt.title('Distribution of data')
plt.xticks(classes, SignNamesList, rotation=80)
default_size = fig.get_size_inches()
fig.set_size_inches( (default_size[0]*4, default_size[1]*2))
plt.show()

# %matplotlib inline

index = random.randint(0, len(X_train))
image = X_train[index].squeeze()

plt.figure(figsize=(4,4))
plt.imshow(image, cmap="gray")
plt.title(SignNamesList[y_train[index]])
print(y_train[index])
# Out:
# 38

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.
#
# **NOTE:** The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
### Preprocess the data here. Preprocessing steps could include normalization, converting to grayscale, etc.
### Feel free to use as many code cells as needed.
import tensorflow as tf
import random
import cv2
import imutils
import numpy as np

IMAGE_SIZE = 32

def gray_scale(X):
    X = 0.299 * X[:, :, :, 0] + 0.587 * X[:, :, :, 1] + 0.114 * X[:, :, :, 2]
    X = (X / 255.).astype(np.float32)
    X = X.reshape(X.shape + (1,))
    return X

def flip_image(image):
    flipped_image = np.fliplr(image)
    return flipped_image

def translate_image(image):
    trans_x = random.randint(0, IMAGE_SIZE)
    trans_y = random.randint(0, IMAGE_SIZE)
    
    #translation matrix
    trans_matrix = np.float32([[1, 0, trans_x], [0, 1, trans_y]])
    
    # Apply transformation to translate the image
    trans_image = cv2.warpAffine(image, trans_matrix, (image.shape[1], image.shape[0]))
    
    return trans_image

# http://stackoverflow.com/questions/24341114/simple-illumination-correction-in-images-opencv-c
def apply_clahe(image):
    #-----Converting image to LAB Color model----------------------------------- 
    lab= cv2.cvtColor(image, cv2.COLOR_RGB2LAB)
    
    #-----Splitting the LAB image to different channels-------------------------
    l, a, b = cv2.split(lab)
    
    #-----Applying CLAHE to L-channel-------------------------------------------
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    
    #-----Merge the CLAHE enhanced L-channel with the a and b channel-----------
    limg = cv2.merge((cl,a,b))
    
    #-----Converting image from LAB Color model to RGB model--------------------
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    
    return final

def process_image(image):
    # Image processing for training the network. Note the many random
    # distortions applied to the image.
    
    # Randomly flip the image horizontally.
    flipped_image = flip_image(image)
    
    # Rotate the image
    angle = random.uniform(0, 360)
    rotated_image = imutils.rotate(flipped_image, angle)
    
    # Translate the image
    translated_image = translate_image(rotated_image)
    
    # Apply CLAHE
    distorted_image = apply_clahe(translated_image)
    
    return distorted_image

# %%
from sklearn.utils import resample

print(X_train.shape)
print(y_train.shape)

# Get the distribution of classes in the training data
classes, class_counts = np.unique(y_train, return_counts=True)

traget_samples = 5000

for label, count in enumerate(class_counts):
    
    to_be_generated = traget_samples - count
    if to_be_generated <= 0:
        print("skipping generation of samples for label: ", label)
        continue
    else:
        print("creating samples: ", to_be_generated, "for label: ", label)
    
    X_sample, y_sample = resample(X_train[y_train == label], y_train[y_train == label], n_samples=to_be_generated, random_state=42)
    
    X_processed = np.zeros_like(X_sample)
    # process each of the images to ensure all the classes have atleast 'traget_samples' examples
    for idx, image in enumerate(X_sample):
        X_processed[idx] = process_image(image)
    
    X_train = np.concatenate((X_train, X_processed))
    y_train = np.concatenate((y_train, y_sample))

print(X_train.shape)
print(y_train.shape)
# Out:
# (34799, 32, 32, 3)
# (34799,)
# creating samples:  4820 for label:  0
# creating samples:  3020 for label:  1
# creating samples:  2990 for label:  2
# creating samples:  3740 for label:  3
# creating samples:  3230 for label:  4
# creating samples:  3350 for label:  5
# creating samples:  4640 for label:  6
# creating samples:  3710 for label:  7
# creating samples:  3740 for label:  8
# creating samples:  3680 for label:  9
# creating samples:  3200 for label:  10
# creating samples:  3830 for label:  11
# creating samples:  3110 for label:  12
# creating samples:  3080 for label:  13
# creating samples:  4310 for label:  14
# creating samples:  4460 for label:  15
# creating samples:  4640 for label:  16
# creating samples:  4010 for label:  17
# creating samples:  3920 for label:  18
# creating samples:  4820 for label:  19
# creating samples:  4700 for label:  20
# creating samples:  4730 for label:  21
# creating samples:  4670 for label:  22
# creating samples:  4550 for label:  23
# creating samples:  4760 for label:  24
# creating samples:  3650 for label:  25
# creating samples:  4460 for label:  26
# creating samples:  4790 for label:  27
# creating samples:  4520 for label:  28
# creating samples:  4760 for label:  29
# creating samples:  4610 for label:  30
# creating samples:  4310 for label:  31
# creating samples:  4790 for label:  32
# creating samples:  4401 for label:  33
# creating samples:  4640 for label:  34
# creating samples:  3920 for label:  35
# creating samples:  4670 for label:  36
# creating samples:  4820 for label:  37
# creating samples:  3140 for label:  38
# creating samples:  4730 for label:  39
# creating samples:  4700 for label:  40
# creating samples:  4790 for label:  41
# creating samples:  4790 for label:  42
# (215000, 32, 32, 3)
# (215000,)

# %%
# Convert images to gray scale
print(X_train.shape)
X_train = gray_scale(X_train)
X_valid = gray_scale(X_valid)
X_test = gray_scale(X_test)
print(X_train.shape)
# Out:
# (215000, 32, 32, 3)
# (215000, 32, 32, 1)

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %% [markdown]
# ### Model Architecture

# %%
import tensorflow as tf

# http://tensorpack.readthedocs.io/en/latest/_modules/tensorpack/models/nonlin.html
def LeakyReLU(x, alpha):
    return tf.maximum(x, alpha * x)

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.

from tensorflow.contrib.layers import flatten

# Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
mu = 0
sigma = 0.1

conv1_W = tf.Variable(tf.truncated_normal(shape=(5, 5, 1, 6), mean = mu, stddev = sigma))
conv1_b = tf.Variable(tf.zeros(6))

conv2_W = tf.Variable(tf.truncated_normal(shape=(5, 5, 6, 16), mean = mu, stddev = sigma))
conv2_b = tf.Variable(tf.zeros(16))

conv3_W = tf.Variable(tf.truncated_normal(shape=(3, 3, 16, 32), mean = mu, stddev = sigma))
conv3_b = tf.Variable(tf.zeros(32))

conv4_W = tf.Variable(tf.truncated_normal(shape=(5, 5, 32, 64), mean = mu, stddev = sigma))
conv4_b = tf.Variable(tf.zeros(64))

fc1_W = tf.Variable(tf.truncated_normal(shape=(16992, 128), mean = mu, stddev = sigma))
fc1_b = tf.Variable(tf.zeros(128))

fc2_W = tf.Variable(tf.truncated_normal(shape=(128, 64), mean = mu, stddev = sigma))
fc2_b = tf.Variable(tf.zeros(64))

fc3_W  = tf.Variable(tf.truncated_normal(shape=(64, 32), mean = mu, stddev = sigma))
fc3_b  = tf.Variable(tf.zeros(32))

fc4_W  = tf.Variable(tf.truncated_normal(shape=(32, n_classes), mean = mu, stddev = sigma))
fc4_b  = tf.Variable(tf.zeros(n_classes))

def LeNet(x):
    
    # Dropout Parameter
    keep_prob = 0.5
    
    # Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x6.
    conv1   = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding='VALID') + conv1_b

    # Activation.
    conv1 = tf.nn.elu(conv1)
    
    # Layer 2: Convolutional. Output = 24x24x16.
    conv2   = tf.nn.conv2d(conv1, conv2_W, strides=[1, 1, 1, 1], padding='VALID') + conv2_b
    
    # Activation.
    conv2 = tf.nn.elu(conv2)
    
    # Dropout
    conv2 = tf.nn.dropout(conv2, keep_prob)
    
    # Layer 3: Convolutional. Output = 8x8x32.
    conv3   = tf.nn.conv2d(conv2, conv3_W, strides=[1, 3, 3, 1], padding='VALID') + conv3_b
    
    # Activation.
    conv3 = tf.nn.elu(conv3)
    
    # Layer 4: Convolutional. Output = 4x4x64.
    conv4   = tf.nn.conv2d(conv3, conv4_W, strides=[1, 1, 1, 1], padding='VALID') + conv4_b
    
    # Activation.
    conv4 = tf.nn.elu(conv4)
    
    #Dropout
    conv4 = tf.nn.dropout(conv4, keep_prob)
    
    # Flatten and concatenate 3 layers.
    # Layer4: 4x4x64 = 1024
    # Layer3: 8*8*32 = 2048
    # Layer2: 24*24*16 = 9216
    # Layer1: 28*28*6 = 4704
    # Output: 16992 (Including Layer1)
    fc0   = tf.concat([flatten(conv4), flatten(conv3), flatten(conv2), flatten(conv1)], 1)
    
    # Layer 5: Fully Connected. Input = 16992. Output = 1024.
    fc1   = tf.matmul(fc0, fc1_W) + fc1_b
    
    # Activation.
    fc1 = tf.nn.elu(fc1)
    
    #Dropout
    fc1 = tf.nn.dropout(fc1, keep_prob)

    # Layer 6: Fully Connected. Input = 120. Output = 84.
    fc2    = tf.matmul(fc1, fc2_W) + fc2_b
    
    # Activation.
    fc2 = tf.nn.elu(fc2)
    
    # Layer 7: Fully Connected. Input = 120. Output = 84.
    fc3    = tf.matmul(fc2, fc3_W) + fc3_b
    
    # Activation.
    fc3 = tf.nn.elu(fc3)
    
    #Dropout
    fc3 = tf.nn.dropout(fc3, keep_prob)
    
    # Layer 5: Fully Connected. Input = 84. Output = n_classes.
    logits = tf.matmul(fc3, fc4_W) + fc4_b
    
    return logits

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.

# Parameters
learning_rate = 0.0001
epochs = 500
batch_size = 128

# L2 Regularization parameter
l2_lambda = 0.0001

# tf Graph input
x = tf.placeholder(tf.float32, [None, 32, 32, 1])
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, n_classes)

# LeNet Model
logits = LeNet(x)

# Define loss and optimizer
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=one_hot_y)

# http://lamda.nju.edu.cn/weixs/project/CNNTricks/CNNTricks.html
l2_loss = l2_lambda*(tf.nn.l2_loss(conv1_W) + 
                     tf.nn.l2_loss(conv2_W) + 
                     tf.nn.l2_loss(fc1_W) + 
                     tf.nn.l2_loss(fc2_W) + 
                     tf.nn.l2_loss(fc3_W))
cost = tf.reduce_mean(cross_entropy + l2_loss)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)

# Training
training_operation = optimizer.minimize(cost)

### Calculate and report the accuracy on the training and validation set.
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

saver = tf.train.Saver()

### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, batch_size):
        end = offset + batch_size
        batch_x, batch_y = X_data[offset:end], y_data[offset:end]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

# http://stackoverflow.com/questions/34199233/how-to-prevent-tensorflow-from-allocating-the-totality-of-a-gpu-memory
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    
    print("Training...")
    print()
    for i in range(epochs):
        X_train, y_train = shuffle(X_train, y_train)
        
        # Training with examples
        for offset in range(0, num_examples, batch_size):
            end = offset + batch_size
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
        
        # Validation
        validation_accuracy = evaluate(X_valid, y_valid)
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    saver.save(sess, './lenet')
    print("Model saved")
    sess.close()
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.184
#
# EPOCH 2 ...
# Validation Accuracy = 0.315
#
# EPOCH 3 ...
# Validation Accuracy = 0.418
#
# EPOCH 4 ...
# Validation Accuracy = 0.488
#
# EPOCH 5 ...
# Validation Accuracy = 0.534
#
# EPOCH 6 ...
# Validation Accuracy = 0.593
#
# EPOCH 7 ...
# Validation Accuracy = 0.624
#
# EPOCH 8 ...
# Validation Accuracy = 0.651
#
# EPOCH 9 ...
# Validation Accuracy = 0.675
#
# EPOCH 10 ...
# Validation Accuracy = 0.705
#
# EPOCH 11 ...
# Validation Accuracy = 0.715
#
# EPOCH 12 ...
# Validation Accuracy = 0.720
#
# EPOCH 13 ...
# Validation Accuracy = 0.738
#
# EPOCH 14 ...
# Validation Accuracy = 0.744
#
# EPOCH 15 ...
# Validation Accuracy = 0.758
#
# EPOCH 16 ...
# Validation Accuracy = 0.772
#
# EPOCH 17 ...
# Validation Accuracy = 0.778
#
# EPOCH 18 ...
# Validation Accuracy = 0.783
#
# EPOCH 19 ...
# Validation Accuracy = 0.787
#
# EPOCH 20 ...
# Validation Accuracy = 0.787
#
# EPOCH 21 ...
# Validation Accuracy = 0.794
#
# EPOCH 22 ...
# Validation Accuracy = 0.804
#
# EPOCH 23 ...
# Validation Accuracy = 0.809
#
# EPOCH 24 ...
# Validation Accuracy = 0.808
#
# EPOCH 25 ...
# Validation Accuracy = 0.818
#
# EPOCH 26 ...
# Validation Accuracy = 0.822
#
# EPOCH 27 ...
# Validation Accuracy = 0.823
#
# EPOCH 28 ...
# Validation Accuracy = 0.836
#
# EPOCH 29 ...
# Validation Accuracy = 0.826
#
# EPOCH 30 ...
# Validation Accuracy = 0.836
#
# EPOCH 31 ...
# Validation Accuracy = 0.844
#
# EPOCH 32 ...
# Validation Accuracy = 0.853
#
# EPOCH 33 ...
# Validation Accuracy = 0.845
#
# EPOCH 34 ...
# Validation Accuracy = 0.853
#
# EPOCH 35 ...
# Validation Accuracy = 0.858
#
# EPOCH 36 ...
# Validation Accuracy = 0.854
#
# EPOCH 37 ...
# Validation Accuracy = 0.859
#
# EPOCH 38 ...
# Validation Accuracy = 0.863
#
# EPOCH 39 ...
# Validation Accuracy = 0.865
#
# EPOCH 40 ...
# Validation Accuracy = 0.868
#
# EPOCH 41 ...
# Validation Accuracy = 0.861
#
# EPOCH 42 ...
# Validation Accuracy = 0.876
#
# EPOCH 43 ...
# Validation Accuracy = 0.867
#
# EPOCH 44 ...
# Validation Accuracy = 0.867
#
# EPOCH 45 ...
# Validation Accuracy = 0.876
#
# EPOCH 46 ...
# Validation Accuracy = 0.874
#
# EPOCH 47 ...
# Validation Accuracy = 0.875
#
# EPOCH 48 ...
# Validation Accuracy = 0.867
#
# EPOCH 49 ...
# Validation Accuracy = 0.880
#
# EPOCH 50 ...
# Validation Accuracy = 0.880
#
# EPOCH 51 ...
# Validation Accuracy = 0.869
#
# EPOCH 52 ...
# Validation Accuracy = 0.880
#
# EPOCH 53 ...
# Validation Accuracy = 0.874
#
# EPOCH 54 ...
# Validation Accuracy = 0.882
#
# EPOCH 55 ...
# Validation Accuracy = 0.880
#
# EPOCH 56 ...
# Validation Accuracy = 0.882
#
# EPOCH 57 ...
# Validation Accuracy = 0.884
#
# EPOCH 58 ...
# Validation Accuracy = 0.880
#
# EPOCH 59 ...
# Validation Accuracy = 0.886
#
# EPOCH 60 ...
# Validation Accuracy = 0.888
#
# EPOCH 61 ...
# Validation Accuracy = 0.883
#
# EPOCH 62 ...
# Validation Accuracy = 0.887
#
# EPOCH 63 ...
# Validation Accuracy = 0.884
#
# EPOCH 64 ...
# Validation Accuracy = 0.893
#
# EPOCH 65 ...
# Validation Accuracy = 0.894
#
# EPOCH 66 ...
# Validation Accuracy = 0.891
#
# EPOCH 67 ...
# Validation Accuracy = 0.883
#
# EPOCH 68 ...
# Validation Accuracy = 0.885
#
# EPOCH 69 ...
# Validation Accuracy = 0.893
#
# EPOCH 70 ...
# Validation Accuracy = 0.886
#
# EPOCH 71 ...
# Validation Accuracy = 0.890
#
# EPOCH 72 ...
# Validation Accuracy = 0.885
#
# EPOCH 73 ...
# Validation Accuracy = 0.891
#
# EPOCH 74 ...
# Validation Accuracy = 0.877
#
# EPOCH 75 ...
# Validation Accuracy = 0.885
#
# EPOCH 76 ...
# Validation Accuracy = 0.880
#
# EPOCH 77 ...
# Validation Accuracy = 0.884
#
# EPOCH 78 ...
# Validation Accuracy = 0.889
#
# EPOCH 79 ...
# Validation Accuracy = 0.884
#
# EPOCH 80 ...
# Validation Accuracy = 0.887
#
# EPOCH 81 ...
# Validation Accuracy = 0.880
#
# EPOCH 82 ...
# Validation Accuracy = 0.885
#
# EPOCH 83 ...
# Validation Accuracy = 0.881
#
# EPOCH 84 ...
# Validation Accuracy = 0.884
#
# EPOCH 85 ...
# Validation Accuracy = 0.884
#
# EPOCH 86 ...
# Validation Accuracy = 0.880
#
# EPOCH 87 ...
# Validation Accuracy = 0.886
#
# EPOCH 88 ...
# Validation Accuracy = 0.882
#
# EPOCH 89 ...
# Validation Accuracy = 0.880
#
# EPOCH 90 ...
# Validation Accuracy = 0.883
#
# EPOCH 91 ...
# Validation Accuracy = 0.890
#
# EPOCH 92 ...
# Validation Accuracy = 0.872
#
# EPOCH 93 ...
# Validation Accuracy = 0.880
#
# EPOCH 94 ...
# Validation Accuracy = 0.887
#
# EPOCH 95 ...
# Validation Accuracy = 0.884
#
# EPOCH 96 ...
# Validation Accuracy = 0.879
#
# EPOCH 97 ...
# Validation Accuracy = 0.886
#
# EPOCH 98 ...
# Validation Accuracy = 0.880
#
# EPOCH 99 ...
# Validation Accuracy = 0.885
#
# EPOCH 100 ...
# Validation Accuracy = 0.891
#
# EPOCH 101 ...
# Validation Accuracy = 0.883
#
# EPOCH 102 ...
# Validation Accuracy = 0.884
#
# EPOCH 103 ...
# Validation Accuracy = 0.882
#
# EPOCH 104 ...
# Validation Accuracy = 0.875
#
# EPOCH 105 ...
# Validation Accuracy = 0.880
#
# EPOCH 106 ...
# Validation Accuracy = 0.885
#
# EPOCH 107 ...
# Validation Accuracy = 0.880
#
# EPOCH 108 ...
# Validation Accuracy = 0.881
#
# EPOCH 109 ...
# Validation Accuracy = 0.883
#
# EPOCH 110 ...
# Validation Accuracy = 0.877
#
# EPOCH 111 ...
# Validation Accuracy = 0.874
#
# EPOCH 112 ...
# Validation Accuracy = 0.880
#
# EPOCH 113 ...
# Validation Accuracy = 0.881
#
# EPOCH 114 ...
# Validation Accuracy = 0.877
#
# EPOCH 115 ...
# Validation Accuracy = 0.885
#
# EPOCH 116 ...
# Validation Accuracy = 0.885
#
# EPOCH 117 ...
# Validation Accuracy = 0.883
#
# EPOCH 118 ...
# Validation Accuracy = 0.879
#
# EPOCH 119 ...
# Validation Accuracy = 0.874
#
# EPOCH 120 ...
# Validation Accuracy = 0.884
#
# EPOCH 121 ...
# Validation Accuracy = 0.885
#
# EPOCH 122 ...
# Validation Accuracy = 0.881
#
# EPOCH 123 ...
# Validation Accuracy = 0.881
#
# EPOCH 124 ...
# Validation Accuracy = 0.886
#
# EPOCH 125 ...
# Validation Accuracy = 0.878
#
# EPOCH 126 ...
# Validation Accuracy = 0.878
#
# EPOCH 127 ...
# Validation Accuracy = 0.880
#
# EPOCH 128 ...
# Validation Accuracy = 0.876
#
# EPOCH 129 ...
# Validation Accuracy = 0.884
#
# EPOCH 130 ...
# Validation Accuracy = 0.878
#
# EPOCH 131 ...
# Validation Accuracy = 0.877
#
# EPOCH 132 ...
# Validation Accuracy = 0.876
#
# EPOCH 133 ...
# Validation Accuracy = 0.881
#
# EPOCH 134 ...
# Validation Accuracy = 0.878
#
# EPOCH 135 ...
# Validation Accuracy = 0.878
#
# EPOCH 136 ...
# Validation Accuracy = 0.885
#
# EPOCH 137 ...
# Validation Accuracy = 0.878
#
# EPOCH 138 ...
# Validation Accuracy = 0.887
#
# EPOCH 139 ...
# Validation Accuracy = 0.882
#
# EPOCH 140 ...
# Validation Accuracy = 0.883
#
# EPOCH 141 ...
# Validation Accuracy = 0.879
#
# EPOCH 142 ...
# Validation Accuracy = 0.879
#
# EPOCH 143 ...
# Validation Accuracy = 0.877
#
# EPOCH 144 ...
# Validation Accuracy = 0.876
#
# EPOCH 145 ...
# Validation Accuracy = 0.881
#
# EPOCH 146 ...
# Validation Accuracy = 0.877
#
# EPOCH 147 ...
# Validation Accuracy = 0.875
#
# EPOCH 148 ...
# Validation Accuracy = 0.876
#
# EPOCH 149 ...
# Validation Accuracy = 0.887
#
# EPOCH 150 ...
# Validation Accuracy = 0.869
#
# EPOCH 151 ...
# Validation Accuracy = 0.877
#
# EPOCH 152 ...
# Validation Accuracy = 0.879
#
# EPOCH 153 ...
# Validation Accuracy = 0.878
#
# EPOCH 154 ...
# Validation Accuracy = 0.881
#
# EPOCH 155 ...
# Validation Accuracy = 0.875
#
# EPOCH 156 ...
# Validation Accuracy = 0.876
#
# EPOCH 157 ...
# Validation Accuracy = 0.875
#
# EPOCH 158 ...
# Validation Accuracy = 0.883
#
# EPOCH 159 ...
# Validation Accuracy = 0.880
#
# EPOCH 160 ...
# Validation Accuracy = 0.873
#
# EPOCH 161 ...
# Validation Accuracy = 0.876
#
# EPOCH 162 ...
# Validation Accuracy = 0.880
#
# EPOCH 163 ...
# Validation Accuracy = 0.885
#
# EPOCH 164 ...
# Validation Accuracy = 0.884
#
# EPOCH 165 ...
# Validation Accuracy = 0.883
#
# EPOCH 166 ...
# Validation Accuracy = 0.882
#
# EPOCH 167 ...
# Validation Accuracy = 0.886
#
# EPOCH 168 ...
# Validation Accuracy = 0.880
#
# EPOCH 169 ...
# Validation Accuracy = 0.879
#
# EPOCH 170 ...
# Validation Accuracy = 0.883
#
# EPOCH 171 ...
# Validation Accuracy = 0.875
#
# EPOCH 172 ...
# Validation Accuracy = 0.881
#
# EPOCH 173 ...
# Validation Accuracy = 0.877
#
# EPOCH 174 ...
# Validation Accuracy = 0.883
#
# EPOCH 175 ...
# Validation Accuracy = 0.876
#
# EPOCH 176 ...
# Validation Accuracy = 0.888
#
# EPOCH 177 ...
# Validation Accuracy = 0.879
#
# EPOCH 178 ...
# Validation Accuracy = 0.887
#
# EPOCH 179 ...
# Validation Accuracy = 0.884
#
# EPOCH 180 ...
# Validation Accuracy = 0.884
#
# EPOCH 181 ...
# Validation Accuracy = 0.878
#
# EPOCH 182 ...
# Validation Accuracy = 0.877
#
# EPOCH 183 ...
# Validation Accuracy = 0.883
#
# EPOCH 184 ...
# Validation Accuracy = 0.887
#
# EPOCH 185 ...
# Validation Accuracy = 0.875
#
# EPOCH 186 ...
# Validation Accuracy = 0.888
#
# EPOCH 187 ...
# Validation Accuracy = 0.884
#
# EPOCH 188 ...
# Validation Accuracy = 0.878
#
# EPOCH 189 ...
# Validation Accuracy = 0.883
#
# EPOCH 190 ...
# Validation Accuracy = 0.876
#
# EPOCH 191 ...
# Validation Accuracy = 0.873
#
# EPOCH 192 ...
# Validation Accuracy = 0.885
#
# EPOCH 193 ...
# Validation Accuracy = 0.888
#
# EPOCH 194 ...
# Validation Accuracy = 0.882
#
# EPOCH 195 ...
# Validation Accuracy = 0.876
#
# EPOCH 196 ...
# Validation Accuracy = 0.878
#
# EPOCH 197 ...
# Validation Accuracy = 0.886
#
# EPOCH 198 ...
# Validation Accuracy = 0.871
#
# EPOCH 199 ...
# Validation Accuracy = 0.878
#
# EPOCH 200 ...
# Validation Accuracy = 0.877
#
# EPOCH 201 ...
# Validation Accuracy = 0.879
#
# EPOCH 202 ...
# Validation Accuracy = 0.884
#
# EPOCH 203 ...
# Validation Accuracy = 0.879
#
# EPOCH 204 ...
# Validation Accuracy = 0.873
#
# EPOCH 205 ...
# Validation Accuracy = 0.875
#
# EPOCH 206 ...
# Validation Accuracy = 0.876
#
# EPOCH 207 ...
# Validation Accuracy = 0.881
#
# EPOCH 208 ...
# Validation Accuracy = 0.875
#
# EPOCH 209 ...
# Validation Accuracy = 0.881
#
# EPOCH 210 ...
# Validation Accuracy = 0.885
#
# EPOCH 211 ...
# Validation Accuracy = 0.879
#
# EPOCH 212 ...
# Validation Accuracy = 0.882
#
# EPOCH 213 ...
# Validation Accuracy = 0.885
#
# EPOCH 214 ...
# Validation Accuracy = 0.888
#
# EPOCH 215 ...
# Validation Accuracy = 0.874
#
# EPOCH 216 ...
# Validation Accuracy = 0.888
#
# EPOCH 217 ...
# Validation Accuracy = 0.878
#
# EPOCH 218 ...
# Validation Accuracy = 0.883
#
# EPOCH 219 ...
# Validation Accuracy = 0.878
#
# EPOCH 220 ...
# Validation Accuracy = 0.880
#
# EPOCH 221 ...
# Validation Accuracy = 0.878
#
# EPOCH 222 ...
# Validation Accuracy = 0.885
#
# EPOCH 223 ...
# Validation Accuracy = 0.880
#
# EPOCH 224 ...
# Validation Accuracy = 0.879
#
# EPOCH 225 ...
# Validation Accuracy = 0.872
#
# EPOCH 226 ...
# Validation Accuracy = 0.883
#
# EPOCH 227 ...
# Validation Accuracy = 0.877
#
# EPOCH 228 ...
# Validation Accuracy = 0.887
#
# EPOCH 229 ...
# Validation Accuracy = 0.880
#
# EPOCH 230 ...
# Validation Accuracy = 0.874
#
# EPOCH 231 ...
# Validation Accuracy = 0.874
#
# EPOCH 232 ...
# Validation Accuracy = 0.882
#
# EPOCH 233 ...
# Validation Accuracy = 0.883
#
# EPOCH 234 ...
# Validation Accuracy = 0.888
#
# EPOCH 235 ...
# Validation Accuracy = 0.885
#
# EPOCH 236 ...
# Validation Accuracy = 0.876
#
# EPOCH 237 ...
# Validation Accuracy = 0.881
#
# EPOCH 238 ...
# Validation Accuracy = 0.879
#
# EPOCH 239 ...
# Validation Accuracy = 0.880
#
# EPOCH 240 ...
# Validation Accuracy = 0.891
#
# EPOCH 241 ...
# Validation Accuracy = 0.888
#
# EPOCH 242 ...
# Validation Accuracy = 0.882
#
# EPOCH 243 ...
# Validation Accuracy = 0.883
#
# EPOCH 244 ...
# Validation Accuracy = 0.882
#
# EPOCH 245 ...
# Validation Accuracy = 0.889
#
# EPOCH 246 ...
# Validation Accuracy = 0.885
#
# EPOCH 247 ...
# Validation Accuracy = 0.886
#
# EPOCH 248 ...
# Validation Accuracy = 0.884
#
# EPOCH 249 ...
# Validation Accuracy = 0.884
#
# EPOCH 250 ...
# Validation Accuracy = 0.883
#
# EPOCH 251 ...
# Validation Accuracy = 0.881
#
# EPOCH 252 ...
# Validation Accuracy = 0.879
#
# EPOCH 253 ...
# Validation Accuracy = 0.879
#
# EPOCH 254 ...
# Validation Accuracy = 0.881
#
# EPOCH 255 ...
# Validation Accuracy = 0.879
#
# EPOCH 256 ...
# Validation Accuracy = 0.877
#
# EPOCH 257 ...
# Validation Accuracy = 0.887
#
# EPOCH 258 ...
# Validation Accuracy = 0.887
#
# EPOCH 259 ...
# Validation Accuracy = 0.883
#
# EPOCH 260 ...
# Validation Accuracy = 0.891
#
# EPOCH 261 ...
# Validation Accuracy = 0.882
#
# EPOCH 262 ...
# Validation Accuracy = 0.883
#
# EPOCH 263 ...
# Validation Accuracy = 0.877
#
# EPOCH 264 ...
# Validation Accuracy = 0.883
#
# EPOCH 265 ...
# Validation Accuracy = 0.876
#
# EPOCH 266 ...
# Validation Accuracy = 0.887
#
# EPOCH 267 ...
# Validation Accuracy = 0.880
#
# EPOCH 268 ...
# Validation Accuracy = 0.881
#
# EPOCH 269 ...
# Validation Accuracy = 0.880
#
# EPOCH 270 ...
# Validation Accuracy = 0.882
#
# EPOCH 271 ...
# Validation Accuracy = 0.888
#
# EPOCH 272 ...
# Validation Accuracy = 0.891
#
# EPOCH 273 ...
# Validation Accuracy = 0.879
#
# EPOCH 274 ...
# Validation Accuracy = 0.889
#
# EPOCH 275 ...
# Validation Accuracy = 0.879
#
# EPOCH 276 ...
# Validation Accuracy = 0.879
#
# EPOCH 277 ...
# Validation Accuracy = 0.882
#
# EPOCH 278 ...
# Validation Accuracy = 0.884
#
# EPOCH 279 ...
# Validation Accuracy = 0.887
#
# EPOCH 280 ...
# Validation Accuracy = 0.886
#
# EPOCH 281 ...
# Validation Accuracy = 0.886
#
# EPOCH 282 ...
# Validation Accuracy = 0.892
#
# EPOCH 283 ...
# Validation Accuracy = 0.882
#
# EPOCH 284 ...
# Validation Accuracy = 0.883
#
# EPOCH 285 ...
# Validation Accuracy = 0.887
#
# EPOCH 286 ...
# Validation Accuracy = 0.885
#
# EPOCH 287 ...
# Validation Accuracy = 0.883
#
# EPOCH 288 ...
# Validation Accuracy = 0.887
#
# EPOCH 289 ...
# Validation Accuracy = 0.886
#
# EPOCH 290 ...
# Validation Accuracy = 0.881
#
# EPOCH 291 ...
# Validation Accuracy = 0.884
#
# EPOCH 292 ...
# Validation Accuracy = 0.881
#
# EPOCH 293 ...
# Validation Accuracy = 0.883
#
# EPOCH 294 ...
# Validation Accuracy = 0.897
#
# EPOCH 295 ...
# Validation Accuracy = 0.885
#
# EPOCH 296 ...
# Validation Accuracy = 0.885
#
# EPOCH 297 ...
# Validation Accuracy = 0.878
#
# EPOCH 298 ...
# Validation Accuracy = 0.891
#
# EPOCH 299 ...
# Validation Accuracy = 0.887
#
# EPOCH 300 ...
# Validation Accuracy = 0.881
#
# EPOCH 301 ...
# Validation Accuracy = 0.887
#
# EPOCH 302 ...
# Validation Accuracy = 0.888
#
# EPOCH 303 ...
# Validation Accuracy = 0.888
#
# EPOCH 304 ...
# Validation Accuracy = 0.887
#
# EPOCH 305 ...
# Validation Accuracy = 0.880
#
# EPOCH 306 ...
# Validation Accuracy = 0.885
#
# EPOCH 307 ...
# Validation Accuracy = 0.887
#
# EPOCH 308 ...
# Validation Accuracy = 0.880
#
# EPOCH 309 ...
# Validation Accuracy = 0.882
#
# EPOCH 310 ...
# Validation Accuracy = 0.883
#
# EPOCH 311 ...
# Validation Accuracy = 0.893
#
# EPOCH 312 ...
# Validation Accuracy = 0.885
#
# EPOCH 313 ...
# Validation Accuracy = 0.883
#
# EPOCH 314 ...
# Validation Accuracy = 0.890
#
# EPOCH 315 ...
# Validation Accuracy = 0.891
#
# EPOCH 316 ...
# Validation Accuracy = 0.890
#
# EPOCH 317 ...
# Validation Accuracy = 0.880
#
# EPOCH 318 ...
# Validation Accuracy = 0.884
#
# EPOCH 319 ...
# Validation Accuracy = 0.890
#
# EPOCH 320 ...
# Validation Accuracy = 0.887
#
# EPOCH 321 ...
# Validation Accuracy = 0.891
#
# EPOCH 322 ...
# Validation Accuracy = 0.889
#
# EPOCH 323 ...
# Validation Accuracy = 0.891
#
# EPOCH 324 ...
# Validation Accuracy = 0.887
#
# EPOCH 325 ...
# Validation Accuracy = 0.890
#
# EPOCH 326 ...
# Validation Accuracy = 0.889
#
# EPOCH 327 ...
# Validation Accuracy = 0.883
#
# EPOCH 328 ...
# Validation Accuracy = 0.887
#
# EPOCH 329 ...
# Validation Accuracy = 0.883
#
# EPOCH 330 ...
# Validation Accuracy = 0.884
#
# EPOCH 331 ...
# Validation Accuracy = 0.889
#
# EPOCH 332 ...
# Validation Accuracy = 0.878
#
# EPOCH 333 ...
# Validation Accuracy = 0.887
#
# EPOCH 334 ...
# Validation Accuracy = 0.884
#
# EPOCH 335 ...
# Validation Accuracy = 0.875
#
# EPOCH 336 ...
# Validation Accuracy = 0.893
#
# EPOCH 337 ...
# Validation Accuracy = 0.898
#
# EPOCH 338 ...
# Validation Accuracy = 0.887
#
# EPOCH 339 ...
# Validation Accuracy = 0.883
#
# EPOCH 340 ...
# Validation Accuracy = 0.887
#
# EPOCH 341 ...
# Validation Accuracy = 0.893
#
# EPOCH 342 ...
# Validation Accuracy = 0.886
#
# EPOCH 343 ...
# Validation Accuracy = 0.881
#
# EPOCH 344 ...
# Validation Accuracy = 0.885
#
# EPOCH 345 ...
# Validation Accuracy = 0.886
#
# EPOCH 346 ...
# Validation Accuracy = 0.888
#
# EPOCH 347 ...
# Validation Accuracy = 0.880
#
# EPOCH 348 ...
# Validation Accuracy = 0.885
#
# EPOCH 349 ...
# Validation Accuracy = 0.892
#
# EPOCH 350 ...
# Validation Accuracy = 0.885
#
# EPOCH 351 ...
# Validation Accuracy = 0.885
#
# EPOCH 352 ...
# Validation Accuracy = 0.890
#
# EPOCH 353 ...
# Validation Accuracy = 0.888
#
# EPOCH 354 ...
# Validation Accuracy = 0.876
#
# EPOCH 355 ...
# Validation Accuracy = 0.880
#
# EPOCH 356 ...
# Validation Accuracy = 0.892
#
# EPOCH 357 ...
# Validation Accuracy = 0.881
#
# EPOCH 358 ...
# Validation Accuracy = 0.890
#
# EPOCH 359 ...
# Validation Accuracy = 0.883
#
# EPOCH 360 ...
# Validation Accuracy = 0.888
#
# EPOCH 361 ...
# Validation Accuracy = 0.881
#
# EPOCH 362 ...
# Validation Accuracy = 0.887
#
# EPOCH 363 ...
# Validation Accuracy = 0.888
#
# EPOCH 364 ...
# Validation Accuracy = 0.888
#
# EPOCH 365 ...
# Validation Accuracy = 0.888
#
# EPOCH 366 ...
# Validation Accuracy = 0.889
#
# EPOCH 367 ...
# Validation Accuracy = 0.884
#
# EPOCH 368 ...
# Validation Accuracy = 0.890
#
# EPOCH 369 ...
# Validation Accuracy = 0.881
#
# EPOCH 370 ...
# Validation Accuracy = 0.881
#
# EPOCH 371 ...
# Validation Accuracy = 0.889
#
# EPOCH 372 ...
# Validation Accuracy = 0.879
#
# EPOCH 373 ...
# Validation Accuracy = 0.883
#
# EPOCH 374 ...
# Validation Accuracy = 0.878
#
# EPOCH 375 ...
# Validation Accuracy = 0.883
#
# EPOCH 376 ...
# Validation Accuracy = 0.884
#
# EPOCH 377 ...
# Validation Accuracy = 0.889
#
# EPOCH 378 ...
# Validation Accuracy = 0.896
#
# EPOCH 379 ...
# Validation Accuracy = 0.884
#
# EPOCH 380 ...
# Validation Accuracy = 0.888
#
# EPOCH 381 ...
# Validation Accuracy = 0.890
#
# EPOCH 382 ...
# Validation Accuracy = 0.883
#
# EPOCH 383 ...
# Validation Accuracy = 0.884
#
# EPOCH 384 ...
# Validation Accuracy = 0.890
#
# EPOCH 385 ...
# Validation Accuracy = 0.888
#
# EPOCH 386 ...
# Validation Accuracy = 0.883
#
# EPOCH 387 ...
# Validation Accuracy = 0.887
#
# EPOCH 388 ...
# Validation Accuracy = 0.891
#
# EPOCH 389 ...
# Validation Accuracy = 0.890
#
# EPOCH 390 ...
# Validation Accuracy = 0.882
#
# EPOCH 391 ...
# Validation Accuracy = 0.881
#
# EPOCH 392 ...
# Validation Accuracy = 0.883
#
# EPOCH 393 ...
# Validation Accuracy = 0.885
#
# EPOCH 394 ...
# Validation Accuracy = 0.886
#
# EPOCH 395 ...
# Validation Accuracy = 0.889
#
# EPOCH 396 ...
# Validation Accuracy = 0.893
#
# EPOCH 397 ...
# Validation Accuracy = 0.887
#
# EPOCH 398 ...
# Validation Accuracy = 0.891
#
# EPOCH 399 ...
# Validation Accuracy = 0.890
#
# EPOCH 400 ...
# Validation Accuracy = 0.881
#
# EPOCH 401 ...
# Validation Accuracy = 0.888
#
# EPOCH 402 ...
# Validation Accuracy = 0.890
#
# EPOCH 403 ...
# Validation Accuracy = 0.884
#
# EPOCH 404 ...
# Validation Accuracy = 0.894
#
# EPOCH 405 ...
# Validation Accuracy = 0.884
#
# EPOCH 406 ...
# Validation Accuracy = 0.883
#
# EPOCH 407 ...
# Validation Accuracy = 0.884
#
# EPOCH 408 ...
# Validation Accuracy = 0.890
#
# EPOCH 409 ...
# Validation Accuracy = 0.876
#
# EPOCH 410 ...
# Validation Accuracy = 0.882
#
# EPOCH 411 ...
# Validation Accuracy = 0.888
#
# EPOCH 412 ...
# Validation Accuracy = 0.887
#
# EPOCH 413 ...
# Validation Accuracy = 0.885
#
# EPOCH 414 ...
# Validation Accuracy = 0.885
#
# EPOCH 415 ...
# Validation Accuracy = 0.881
#
# EPOCH 416 ...
# Validation Accuracy = 0.884
#
# EPOCH 417 ...
# Validation Accuracy = 0.884
#
# EPOCH 418 ...
# Validation Accuracy = 0.886
#
# EPOCH 419 ...
# Validation Accuracy = 0.890
#
# EPOCH 420 ...
# Validation Accuracy = 0.890
#
# EPOCH 421 ...
# Validation Accuracy = 0.889
#
# EPOCH 422 ...
# Validation Accuracy = 0.883
#
# EPOCH 423 ...
# Validation Accuracy = 0.887
#
# EPOCH 424 ...
# Validation Accuracy = 0.888
#
# EPOCH 425 ...
# Validation Accuracy = 0.890
#
# EPOCH 426 ...
# Validation Accuracy = 0.886
#
# EPOCH 427 ...
# Validation Accuracy = 0.884
#
# EPOCH 428 ...
# Validation Accuracy = 0.885
#
# EPOCH 429 ...
# Validation Accuracy = 0.889
#
# EPOCH 430 ...
# Validation Accuracy = 0.892
#
# EPOCH 431 ...
# Validation Accuracy = 0.887
#
# EPOCH 432 ...
# Validation Accuracy = 0.896
#
# EPOCH 433 ...
# Validation Accuracy = 0.893
#
# EPOCH 434 ...
# Validation Accuracy = 0.892
#
# EPOCH 435 ...
# Validation Accuracy = 0.885
#
# EPOCH 436 ...
# Validation Accuracy = 0.887
#
# EPOCH 437 ...
# Validation Accuracy = 0.893
#
# EPOCH 438 ...
# Validation Accuracy = 0.885
#
# EPOCH 439 ...
# Validation Accuracy = 0.890
#
# EPOCH 440 ...
# Validation Accuracy = 0.888
#
# EPOCH 441 ...
# Validation Accuracy = 0.884
#
# EPOCH 442 ...
# Validation Accuracy = 0.885
#
# EPOCH 443 ...
# Validation Accuracy = 0.893
#
# EPOCH 444 ...
# Validation Accuracy = 0.891
#
# EPOCH 445 ...
# Validation Accuracy = 0.890
#
# EPOCH 446 ...
# Validation Accuracy = 0.884
#
# EPOCH 447 ...
# Validation Accuracy = 0.891
#
# EPOCH 448 ...
# Validation Accuracy = 0.891
#
# EPOCH 449 ...
# Validation Accuracy = 0.891
#
# EPOCH 450 ...
# Validation Accuracy = 0.883
#
# EPOCH 451 ...
# Validation Accuracy = 0.891
#
# EPOCH 452 ...
# Validation Accuracy = 0.888
#
# EPOCH 453 ...
# Validation Accuracy = 0.883
#
# EPOCH 454 ...
# Validation Accuracy = 0.883
#
# EPOCH 455 ...
# Validation Accuracy = 0.885
#
# EPOCH 456 ...
# Validation Accuracy = 0.891
#
# EPOCH 457 ...
# Validation Accuracy = 0.893
#
# EPOCH 458 ...
# Validation Accuracy = 0.887
#
# EPOCH 459 ...
# Validation Accuracy = 0.889
#
# EPOCH 460 ...
# Validation Accuracy = 0.889
#
# EPOCH 461 ...
# Validation Accuracy = 0.893
#
# EPOCH 462 ...
# Validation Accuracy = 0.887
#
# EPOCH 463 ...
# Validation Accuracy = 0.887
#
# EPOCH 464 ...
# Validation Accuracy = 0.881
#
# EPOCH 465 ...
# Validation Accuracy = 0.890
#
# EPOCH 466 ...
# Validation Accuracy = 0.889
#
# EPOCH 467 ...
# Validation Accuracy = 0.890
#
# EPOCH 468 ...
# Validation Accuracy = 0.887
#
# EPOCH 469 ...
# Validation Accuracy = 0.888
#
# EPOCH 470 ...
# Validation Accuracy = 0.892
#
# EPOCH 471 ...
# Validation Accuracy = 0.886
#
# EPOCH 472 ...
# Validation Accuracy = 0.880
#
# EPOCH 473 ...
# Validation Accuracy = 0.886
#
# EPOCH 474 ...
# Validation Accuracy = 0.880
#
# EPOCH 475 ...
# Validation Accuracy = 0.885
#
# EPOCH 476 ...
# Validation Accuracy = 0.888
#
# EPOCH 477 ...
# Validation Accuracy = 0.894
#
# EPOCH 478 ...
# Validation Accuracy = 0.892
#
# EPOCH 479 ...
# Validation Accuracy = 0.884
#
# EPOCH 480 ...
# Validation Accuracy = 0.890
#
# EPOCH 481 ...
# Validation Accuracy = 0.887
#
# EPOCH 482 ...
# Validation Accuracy = 0.882
#
# EPOCH 483 ...
# Validation Accuracy = 0.889
#
# EPOCH 484 ...
# Validation Accuracy = 0.887
#
# EPOCH 485 ...
# Validation Accuracy = 0.896
#
# EPOCH 486 ...
# Validation Accuracy = 0.886
#
# EPOCH 487 ...
# Validation Accuracy = 0.890
#
# EPOCH 488 ...
# Validation Accuracy = 0.896
#
# EPOCH 489 ...
# Validation Accuracy = 0.883
#
# EPOCH 490 ...
# Validation Accuracy = 0.883
#
# EPOCH 491 ...
# Validation Accuracy = 0.881
#
# EPOCH 492 ...
# Validation Accuracy = 0.884
#
# EPOCH 493 ...
# Validation Accuracy = 0.879
#
# EPOCH 494 ...
# Validation Accuracy = 0.878
#
# EPOCH 495 ...
# Validation Accuracy = 0.889
#
# EPOCH 496 ...
# Validation Accuracy = 0.887
#
# EPOCH 497 ...
# Validation Accuracy = 0.882
#
# EPOCH 498 ...
# Validation Accuracy = 0.897
#
# EPOCH 499 ...
# Validation Accuracy = 0.888
#
# EPOCH 500 ...
# Validation Accuracy = 0.886
#
# Model saved

# %%
# Testing the saved model
with tf.Session() as sess:
    print("Testing...")
    saver.restore(sess, tf.train.latest_checkpoint('.'))
    test_accuracy = evaluate(X_test, y_test)
    print("Test Accuracy = {:.3f}".format(test_accuracy))
    
    sess.close()
# Out:
# Testing...
# Test Accuracy = 0.871

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.

import os
from os.path import splitext, basename
import skimage.io as io
import matplotlib.pyplot as plt

names = []
images = []
for filename in os.listdir('./test-signs/'):
    if filename.endswith(".jpeg"): 
        fName, ext = os.path.splitext(filename)
        names.append(fName)
        continue
    else:
        continue

test_images = io.imread_collection('./test-signs/*.jpeg')
plt.figure(figsize=(8,8))

for index in range(len(test_images)):
    plt.imshow(test_images[index])
    plt.title(names[index])
    plt.show()

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
### Run the predictions here and use the model to output the prediction for each image.
### Make sure to pre-process the images with the same pre-processing pipeline used earlier.
### Feel free to use as many code cells as needed.
import numpy as np
from skimage.transform import resize

# Resize the test_images to size 32x32x3
resized_images = np.zeros((len(test_images), 32, 32, 3))

for i, image in enumerate(test_images):
    resized_images[i] = resize(image, (32, 32, 3))

print(resized_images.shape)
# Out:
# (24, 32, 32, 3)

# %%
# Apply gray scaling on test_images
test_gray_images = gray_scale(resized_images)

print(test_gray_images.shape)
# Out:
# (24, 32, 32, 1)

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 16 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tk.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.
import tensorflow as tf
import matplotlib.gridspec as gridspec

softmax = tf.nn.softmax(logits)
top_k_value, top_k_index = tf.nn.top_k(softmax, k=5, sorted=True)

with tf.Session() as sess:
    saved_model = tf.train.import_meta_graph('./lenet.meta')
    saved_model.restore(sess, tf.train.latest_checkpoint('.'))
    top_k_values, top_k_indices = sess.run([top_k_value, top_k_index], feed_dict={x: test_gray_images})
    print(top_k_values)
    print(top_k_indices)

# https://github.com/hello2all/CarND-Traffic-Sign-Classifier-Project/blob/master/Traffic_Sign_Classifier.ipynb
for i in range(len(test_images)):
    plt.figure(figsize = (5,1.5))
    gs = gridspec.GridSpec(1, 2, width_ratios=[2,3])
    plt.subplot(gs[0])
    plt.imshow(test_images[i])
    plt.axis('off')
    plt.subplot(gs[1])
    plt.barh(6-np.arange(5),top_k_values[i], align='center')
    for i_label in range(5):
        plt.text(top_k_values[i][i_label]+.02,6-i_label-.25,
            SignNames[SignNames['ClassId'] == top_k_indices[i][i_label]]['SignName'].values[0])
    plt.axis('off')
    plt.text(0,6.95,names[i])
    plt.show()
# Out:
# [[ 0.33763927  0.32675472  0.20257506  0.09003632  0.01013959]
#  [ 0.31372499  0.14231057  0.10224912  0.06590944  0.06270266]
#  [ 0.32524315  0.10251664  0.09480634  0.07500642  0.05026124]
#  [ 0.12200892  0.11700795  0.10361011  0.08101107  0.07937123]
#  [ 0.21510145  0.19859619  0.16683613  0.13210073  0.07110006]
#  [ 0.32505456  0.16401596  0.07750219  0.07403454  0.05990122]
#  [ 0.19534995  0.15030411  0.10113295  0.08080706  0.08067537]
#  [ 0.08631117  0.08020085  0.07441355  0.06483783  0.06422549]
#  [ 0.26139534  0.20086704  0.11818297  0.07817769  0.06224493]
#  [ 0.0645738   0.05136865  0.04179644  0.04035579  0.03839545]
#  [ 0.05827998  0.05490313  0.05326972  0.05052058  0.04956118]
#  [ 0.45815453  0.14252597  0.10589749  0.05844669  0.0474221 ]
#  [ 0.22624937  0.12380336  0.09600949  0.0925385   0.07588034]
#  [ 0.20423777  0.16351496  0.09626549  0.06724287  0.05372358]
#  [ 0.09920765  0.06213073  0.06158323  0.05665872  0.05444279]
#  [ 0.16792718  0.12401682  0.12318224  0.10111672  0.07650186]
#  [ 0.31665111  0.18713969  0.16362715  0.15749826  0.03233888]
#  [ 0.16553013  0.14500627  0.13413925  0.08205056  0.07420404]
#  [ 0.30840182  0.26317129  0.15078752  0.12450569  0.03290145]
#  [ 0.1357231   0.08803491  0.08444385  0.07665028  0.07181592]
#  [ 0.19153053  0.17932379  0.1256872   0.08876618  0.0680026 ]
#  [ 0.05720568  0.04827387  0.0482429   0.04531331  0.04478709]
#  [ 0.22504064  0.18461947  0.17833821  0.08195344  0.05965206]
#  [ 0.08348101  0.06576568  0.0655955   0.06326514  0.06185787]]
# [[16  9 15 10  0]
#  [16 10  9  3  5]
#  [16 10 15 32  9]
#  [ 7  0  4 40  2]
#  [16 10  9 15  3]
#  [16 10  9  5  3]
#  [16  9 10  3 15]
#  [ 9 33 39 10 38]
#  [ 9 16 15 10  0]
#  [16  6 32 30  9]
#  [40  9  7  8  0]
#  [16 10  9  3 15]
#  [16  3 10  5  9]
#  [ 9 15 16 10  4]
#  [29 22 24 28 25]
#  [16 10  9  7  5]
#  [16  9 15 10  3]
#  [ 3  5 16 10  8]
#  [ 9 16 15 10  3]
#  [16  7  0  9 15]
#  [16  0  9  7  1]
#  [20  5  3 16 10]
#  [ 9 15 16 10  3]
#  [16 32 10  9 15]]

# %% [markdown]
# ---
#
# ## Step 4: Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it maybe having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")

# %% [markdown]
# ### Question 9
#
# Discuss how you used the visual output of your trained network's feature maps to show that it had learned to look for interesting characteristics in traffic sign images

# %% [markdown]
# **Answer:**

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.
